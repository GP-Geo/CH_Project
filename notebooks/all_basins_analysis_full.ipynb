# %% [markdown]
# # Channel Head Coupling & Lengthwise Asymmetry Analysis - All 18 Basins
#
# This notebook performs full analysis of coupled channel heads for **all 18 basins** from Goren & Shelef (2024):
#
# - **Coupling Analysis**: Detecting spatially touching channel head basins
# - **Lengthwise Asymmetry (ΔL)**: Measuring flow path length differences
#
# ## Basins Analyzed (from Table A1):
#
# | Basin | Location | z_th (m) |
# |-------|----------|----------|
# | Central Mountain Range | Taiwan | 80 |
# | Clan Alpine Mountains | Nevada, USA | 1700 |
# | Daquing Shan | China | 1200 |
# | Finisterre Range | Papua New Guinea | 400 |
# | Humboldt Range | Nevada, USA | 1450 |
# | Inyo Mountains | California, USA | 1200 |
# | Kammanassie Mountains | South Africa | 630 |
# | Lüliang Mountains | China | 1100 |
# | Panamint Range | California, USA | 800 |
# | Sakhalin Mountains | Russia | 60 |
# | Sierra del Valle Fértil | Argentina | 1050 |
# | Sierra Madre del Sur | Mexico | 380 |
# | Sierra Nevada | Spain | 1200 |
# | Sierra Pie de Palo | Argentina | 650 |
# | Toano Range | Nevada, USA | 1710 |
# | Troodos Mountains | Cyprus | 200 |
# | Tsugaru Peninsula | Japan | 30 |
# | Yoro Mountains | Japan | 130 |

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import topotoolbox as tt3

# Add project root so "channel_heads" package is visible
project_root = pathlib.Path("/Users/guypi/Projects/channel-heads")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Core analysis imports
from channel_heads import (
    CouplingAnalyzer,
    first_meet_pairs_for_outlet,
    outlet_node_ids_from_streampoi,
    # Lengthwise asymmetry
    LengthwiseAsymmetryAnalyzer,
    compute_asymmetry_statistics,
    merge_coupling_and_asymmetry,
    # Basin configuration
    get_z_th,
    get_basin_config,
    get_reference_delta_L,
    BASIN_CONFIG,
)

# Plotting utilities
from channel_heads.plotting_utils import (
    plot_coupled_pair,
    plot_outlet_view,
    plot_all_coupled_pairs_for_outlet,
)

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)
# %matplotlib inline

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## 2. Basin Configuration
#
# Load basin parameters from Goren & Shelef (2024) Table A1. All 18 basins are configured with their respective DEM paths and paper names.

# %%
# Define basins to analyze with their DEM paths
DATA_DIR = pathlib.Path("/Users/guypi/Projects/channel-heads/data/cropped_DEMs")
OUTPUT_DIR = pathlib.Path("/Users/guypi/Projects/channel-heads/data/outputs")

# All 18 basins from Goren & Shelef (2024)
BASINS_TO_ANALYZE = {
    # Original 7 basins
    "inyo": {
        "dem_path": DATA_DIR / "Inyo_strm_crop.tif",
        "paper_name": "inyo",
    },
    "humboldt": {
        "dem_path": DATA_DIR / "Humboldt_strm_crop.tif",
        "paper_name": "humboldt",
    },
    "calnalpine": {
        "dem_path": DATA_DIR / "CalnAlpine_strm_crop.tif",
        "paper_name": "clanalpine",
    },
    "daqing": {
        "dem_path": DATA_DIR / "Daqing_strm_crop.tif",
        "paper_name": "daqing",
    },
    "kammanasie": {
        "dem_path": DATA_DIR / "Kammanasie_strm_crop.tif",
        "paper_name": "kammanassie",
    },
    "luliang": {
        "dem_path": DATA_DIR / "Luliang_strm_crop.tif",
        "paper_name": "luliang",
    },
    "finisterre": {
        "dem_path": DATA_DIR / "Finisterre_strm_crop.tif",
        "paper_name": "finisterre",
    },
    # Additional 11 basins
    "taiwan": {
        "dem_path": DATA_DIR / "Taiwan_strm_crop.tif",
        "paper_name": "taiwan",
    },
    "panamint": {
        "dem_path": DATA_DIR / "Panamint_strm_crop.tif",
        "paper_name": "panamint",
    },
    "sakhalin": {
        "dem_path": DATA_DIR / "Sakhalin_strm_crop.tif",
        "paper_name": "sakhalin",
    },
    "vallefertil": {
        "dem_path": DATA_DIR / "ValleFertil_strm_crop.tif",
        "paper_name": "vallefertil",
    },
    "sierramadre": {
        "dem_path": DATA_DIR / "SierraMadre_strm_crop.tif",
        "paper_name": "sierramadre",
    },
    "sierranevadaspain": {
        "dem_path": DATA_DIR / "SierraNevadaSpain_strm_crop.tif",
        "paper_name": "sierranevada_spain",
    },
    "piedepalo": {
        "dem_path": DATA_DIR / "PieDePalo_strm_crop.tif",
        "paper_name": "piedepalo",
    },
    "toano": {
        "dem_path": DATA_DIR / "Toano_strm_crop.tif",
        "paper_name": "toano",
    },
    "troodos": {
        "dem_path": DATA_DIR / "Troodos_strm_crop.tif",
        "paper_name": "troodos",
    },
    "tsugaru": {
        "dem_path": DATA_DIR / "Tsugaru_strm_crop.tif",
        "paper_name": "tsugaru",
    },
    "yoro": {
        "dem_path": DATA_DIR / "Yoro_strm_crop.tif",
        "paper_name": "yoro",
    },
}

# Stream extraction threshold (default: 145)
STREAM_THRESHOLD = 145

# Show basin configurations
print("=" * 80)
print("Basin Configuration from Goren & Shelef (2024)")
print(f"Total basins: {len(BASINS_TO_ANALYZE)}")
print(f"Stream threshold: {STREAM_THRESHOLD}")
print("=" * 80)

for name, config in BASINS_TO_ANALYZE.items():
    basin_config = get_basin_config(config["paper_name"])
    ref_delta_L = get_reference_delta_L(config["paper_name"])
    dem_exists = config['dem_path'].exists()
    status = "OK" if dem_exists else "MISSING"
    print(f"\n{basin_config['full_name']} [{status}]")
    print(f"  z_th: {basin_config['z_th']} m")
    print(f"  z_max: {basin_config['z_max']} m")
    print(f"  lat: {basin_config['lat']}")
    print(f"  theta (concavity): {basin_config['theta']:.2f}")
    print(f"  Reference delta_L: {ref_delta_L['median']:.2f} ({ref_delta_L['p25']:.2f} - {ref_delta_L['p75']:.2f})")
# Out:
# ================================================================================
# Basin Configuration from Goren & Shelef (2024)
# Total basins: 18
# Stream threshold: 145
# ================================================================================
#
# Inyo Mountains, California [OK]
#   z_th: 1200 m
#   z_max: 3363 m
#   lat: 36.71
#   theta (concavity): 0.35
#   Reference delta_L: 0.17 (0.08 - 0.34)
#
# Humboldt Range, Nevada [OK]
#   z_th: 1450 m
#   z_max: 2984 m
#   lat: 40.52
#   theta (concavity): 0.46
#   Reference delta_L: 0.34 (0.13 - 0.61)
#
# Clan Alpine Mountains, Nevada [OK]
#   z_th: 1700 m
#   z_max: 2677 m
#   lat: 39.69
#   theta (concavity): 0.34
#   Reference delta_L: 0.27 (0.12 - 0.48)
#
# Daquing Shan, China [OK]
#   z_th: 1200 m
#   z_max: 2293 m
#   lat: 40.71
#   theta (concavity): 0.55
#   Reference delta_L: 0.82 (0.40 - 1.21)
#
# Kammanassie Mountains, South Africa [OK]
#   z_th: 630 m
#   z_max: 1935 m
#   lat: -33.62
#   theta (concavity): 0.39
#   Reference delta_L: 0.35 (0.17 - 0.62)
#
# Lüliang Mountains, China [OK]
#   z_th: 1100 m
#   z_max: 2391 m
#   lat: 39.27
#   theta (concavity): 0.37
#   Reference delta_L: 0.46 (0.21 - 0.77)
#
# Finisterre Range, Papua New Guinea [OK]
#   z_th: 400 m
#   z_max: 4096 m
#   lat: -5.95
#   theta (concavity): 0.64
#   Reference delta_L: 0.93 (0.49 - 1.37)
#
# Central Mountain Range, Taiwan [OK]
#   z_th: 80 m
#   z_max: 3917 m
#   lat: 23.47
#   theta (concavity): 0.59
#   Reference delta_L: 1.16 (0.60 - 1.58)
#
# Panamint Range, California [OK]
#   z_th: 800 m
#   z_max: 3344 m
#   lat: 36.17
#   theta (concavity): 0.50
#   Reference delta_L: 0.40 (0.13 - 0.80)
#
# Sakhalin Mountains, Russia [OK]
#   z_th: 60 m
#   z_max: 1028 m
#   lat: 47.07
#   theta (concavity): 0.42
#   Reference delta_L: 0.56 (0.25 - 1.02)
#
# Sierra del Valle Fértil, Argentina [OK]
#   z_th: 1050 m
#   z_max: 2311 m
#   lat: -30.44
#   theta (concavity): 0.54
#   Reference delta_L: 0.90 (0.45 - 1.36)
#
# Sierra Madre del Sur, Mexico [OK]
#   z_th: 380 m
#   z_max: 3105 m
#   lat: 17.52
#   theta (concavity): 0.67
#   Reference delta_L: 1.01 (0.52 - 1.47)
#
# Sierra Nevada, Spain [OK]
#   z_th: 1200 m
#   z_max: 3446 m
#   lat: 37.05
#   theta (concavity): 0.24
#   Reference delta_L: 0.19 (0.08 - 0.34)
#
# Sierra Pie de Palo, Argentina [OK]
#   z_th: 650 m
#   z_max: 3157 m
#   lat: -31.32
#   theta (concavity): 0.25
#   Reference delta_L: 0.17 (0.07 - 0.34)
#
# Toano Range, Nevada [OK]
#   z_th: 1710 m
#   z_max: 2914 m
#   lat: 40.5
#   theta (concavity): 0.22
#   Reference delta_L: 0.18 (0.09 - 0.32)
#
# Troodos Mountains, Cyprus [OK]
#   z_th: 200 m
#   z_max: 1949 m
#   lat: 34.94
#   theta (concavity): 0.51
#   Reference delta_L: 0.84 (0.42 - 1.26)
#
# Tsugaru Peninsula, Japan [OK]
#   z_th: 30 m
#   z_max: 666 m
#   lat: 40.97
#   theta (concavity): 0.37
#   Reference delta_L: 0.53 (0.28 - 0.82)
#
# Yoro Mountains, Japan [OK]
#   z_th: 130 m
#   z_max: 885 m
#   lat: 35.28
#   theta (concavity): 0.82
#   Reference delta_L: 1.38 (0.96 - 1.65)

# %% [markdown]
# ## 3. Analysis Functions

# %%
def load_and_prepare_basin(basin_name, dem_path, z_th, stream_threshold=145):
    """
    Load DEM, apply z_th mask, and create stream network.
    
    Parameters
    ----------
    basin_name : str
        Name of the basin for logging.
    dem_path : Path
        Path to the DEM GeoTIFF file.
    z_th : int
        Elevation threshold for masking (from paper Table A1).
    stream_threshold : int
        Drainage area threshold for stream extraction (default: 145).
    
    Returns
    -------
    dict : Dictionary with dem, fd, s keys.
    """
    print(f"Loading {basin_name}...")
    
    # Load DEM
    dem = tt3.read_tif(str(dem_path))
    print(f"  DEM shape: {dem.z.shape}")
    print(f"  Elevation range: {np.nanmin(dem.z):.0f} - {np.nanmax(dem.z):.0f} m")
    
    # Apply z_th mask (mask elevations below threshold)
    dem.z[dem.z < z_th] = np.nan
    valid_pct = 100 * np.sum(~np.isnan(dem.z)) / dem.z.size
    print(f"  Applied z_th={z_th} m mask: {valid_pct:.1f}% valid pixels")
    
    # Create flow and stream objects
    fd = tt3.FlowObject(dem)
    s = tt3.StreamObject(fd, threshold=stream_threshold)
    
    # Count network features
    n_outlets = np.sum(s.streampoi('outlets'))
    n_heads = np.sum(s.streampoi('channelheads'))
    n_confluences = np.sum(s.streampoi('confluences'))
    print(f"  Stream network (threshold={stream_threshold}):")
    print(f"    Outlets: {n_outlets}, Heads: {n_heads}, Confluences: {n_confluences}")
    
    return {"dem": dem, "fd": fd, "s": s}


def run_full_analysis(s, fd, dem, lat, outlets=None, max_outlets=None):
    """
    Run coupling + lengthwise asymmetry analysis for all outlets.
    
    Parameters
    ----------
    s : StreamObject
        TopoToolbox StreamObject with stream network topology.
    fd : FlowObject
        TopoToolbox FlowObject with flow directions.
    dem : GridObject
        Digital elevation model.
    lat : float
        Latitude of the study area in degrees. Used to convert
        pixel distances to meters for proper L values.
    outlets : list, optional
        List of outlet node IDs. If None, all outlets are used.
    max_outlets : int, optional
        Maximum number of outlets to process.
    
    Returns
    -------
    pd.DataFrame : Combined results with coupling and asymmetry metrics.
    """
    if outlets is None:
        outlets = outlet_node_ids_from_streampoi(s)
    outlets = [int(o) for o in outlets]
    
    if max_outlets and len(outlets) > max_outlets:
        print(f"  Limiting to first {max_outlets} outlets (of {len(outlets)})")
        outlets = outlets[:max_outlets]
    
    # Create analyzers
    coupling_an = CouplingAnalyzer(fd, s, dem, connectivity=8)
    # Pass latitude to get proper meter conversion for L values
    asymmetry_an = LengthwiseAsymmetryAnalyzer(s, dem, lat=lat)
    
    coupling_dfs = []
    asymmetry_dfs = []
    
    for idx, outlet in enumerate(outlets, 1):
        print(f"  [{idx}/{len(outlets)}] outlet={outlet}", end="", flush=True)
        
        # Get first-meet pairs
        pairs_at_confluence, basin_heads = first_meet_pairs_for_outlet(s, outlet)
        
        if not pairs_at_confluence:
            print(" (no pairs)")
            continue
        
        # Coupling analysis
        coupling_an._mask_cache.clear()
        df_coupling = coupling_an.evaluate_pairs_for_outlet(outlet, pairs_at_confluence)
        
        # Asymmetry analysis
        asymmetry_an.clear_cache()
        df_asymmetry = asymmetry_an.evaluate_pairs_for_outlet(outlet, pairs_at_confluence)
        
        n_pairs = len(df_coupling)
        n_touching = df_coupling['touching'].sum() if not df_coupling.empty else 0
        print(f" ({n_pairs} pairs, {n_touching} touching)")
        
        if not df_coupling.empty:
            coupling_dfs.append(df_coupling)
        if not df_asymmetry.empty:
            asymmetry_dfs.append(df_asymmetry)
    
    # Combine results
    if not coupling_dfs:
        return pd.DataFrame()
    
    df_coupling_all = pd.concat(coupling_dfs, ignore_index=True)
    df_asymmetry_all = pd.concat(asymmetry_dfs, ignore_index=True)
    
    # Merge coupling and asymmetry results
    df_combined = merge_coupling_and_asymmetry(df_coupling_all, df_asymmetry_all)
    df_combined.sort_values(["outlet", "confluence", "head_1", "head_2"], inplace=True, ignore_index=True)
    
    return df_combined

# %% [markdown]
# ## 4. Run Analysis for All 18 Basins

# %%
# Store results for each basin
basin_results = {}
basin_data = {}

for basin_name, config in BASINS_TO_ANALYZE.items():
    # Skip if DEM doesn't exist
    if not config["dem_path"].exists():
        print(f"\nSkipping {basin_name}: DEM not found at {config['dem_path']}")
        continue
    
    print("\n" + "=" * 80)
    print(f"Processing: {basin_name.upper()}")
    print("=" * 80)
    
    # Get basin configuration from paper (includes z_th and lat)
    basin_config = get_basin_config(config["paper_name"])
    z_th = basin_config["z_th"]
    lat = basin_config["lat"]
    
    print(f"  Using z_th={z_th} m, lat={lat}")
    
    # Load and prepare basin
    data = load_and_prepare_basin(
        basin_name=basin_name,
        dem_path=config["dem_path"],
        z_th=z_th,
        stream_threshold=STREAM_THRESHOLD,
    )
    basin_data[basin_name] = data
    
    # Run analysis with latitude for proper meter conversion
    print(f"\nRunning coupling + asymmetry analysis...")
    df_results = run_full_analysis(
        s=data["s"],
        fd=data["fd"],
        dem=data["dem"],
        lat=lat,  # Pass latitude for proper L values in meters
    )
    basin_results[basin_name] = df_results
    
    # Save results
    output_dir = OUTPUT_DIR / basin_name
    output_dir.mkdir(parents=True, exist_ok=True)
    output_path = output_dir / "coupling_asymmetry_results.csv"
    df_results.to_csv(output_path, index=False)
    print(f"\nSaved results to: {output_path}")

print("\n" + "=" * 80)
print(f"All basins processed! ({len(basin_results)} basins)")
print("=" * 80)
# Out:
# ================================================================================
# Processing: INYO
# ================================================================================
#   Using z_th=1200 m, lat=36.71
# Loading inyo...
#   DEM shape: (289, 284)
#   Elevation range: 329 - 3363 m
#   Applied z_th=1200 m mask: 65.4% valid pixels
#   Stream network (threshold=145):
#     Outlets: 41, Heads: 95, Confluences: 52
#
# Running coupling + asymmetry analysis...
#   [1/41] outlet=0 (no pairs)
#   [2/41] outlet=2 (3 pairs, 1 touching)
#   [3/41] outlet=3 (no pairs)
#   [4/41] outlet=4 (1 pairs, 1 touching)
#   [5/41] outlet=5 (1 pairs, 1 touching)
#   [6/41] outlet=6 (1 pairs, 0 touching)
#   [7/41] outlet=9 (3 pairs, 1 touching)
#   [8/41] outlet=50 (1 pairs, 0 touching)
#   [9/41] outlet=93 (no pairs)
#   [10/41] outlet=94 (6 pairs, 2 touching)
#   [11/41] outlet=166 (no pairs)
#   [12/41] outlet=178 (1 pairs, 0 touching)
#   [13/41] outlet=240 (no pairs)
#   [14/41] outlet=268 (no pairs)
#   [15/41] outlet=335 (3 pairs, 1 touching)
#   [16/41] outlet=345 (no pairs)
#   [17/41] outlet=420 (3 pairs, 0 touching)
#   [18/41] outlet=492 (1 pairs, 1 touching)
#   [19/41] outlet=655 (1 pairs, 1 touching)
#   [20/41] outlet=712 (1 pairs, 0 touching)
#   [21/41] outlet=763 (no pairs)
#   [22/41] outlet=805 (no pairs)
#   [23/41] outlet=815 (1 pairs, 0 touching)
#   [24/41] outlet=848 (6 pairs, 0 touching)
#   [25/41] outlet=901 (no pairs)
#   [26/41] outlet=1322 (no pairs)
#   [27/41] outlet=1377 (no pairs)
#   [28/41] outlet=1558 (6 pairs, 1 touching)
#   [29/41] outlet=1616 (10 pairs, 4 touching)
#   [30/41] outlet=1724 (1 pairs, 1 touching)
#   [31/41] outlet=1725 (no pairs)
#   [32/41] outlet=1756 (3 pairs, 0 touching)
#   [33/41] outlet=1844 (15 pairs, 2 touching)
#   [34/41] outlet=2014 (no pairs)
#   [35/41] outlet=2015 (no pairs)
#   [36/41] outlet=2046 (21 pairs, 3 touching)
#   [37/41] outlet=2124 (15 pairs, 4 touching)
#   [38/41] outlet=2157 (15 pairs, 4 touching)
#   [39/41] outlet=2158 (no pairs)
#   [40/41] outlet=2177 (no pairs)
#   [41/41] outlet=2190 (no pairs)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/inyo/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: HUMBOLDT
# ================================================================================
#   Using z_th=1450 m, lat=40.52
# Loading humboldt...
#   DEM shape: (320, 219)
#   Elevation range: 1313 - 2984 m
#   Applied z_th=1450 m mask: 84.5% valid pixels
#   Stream network (threshold=145):
#     Outlets: 53, Heads: 112, Confluences: 59
#
# Running coupling + asymmetry analysis...
#   [1/53] outlet=0 (1 pairs, 0 touching)
#   [2/53] outlet=2 (no pairs)
#   [3/53] outlet=8 (1 pairs, 1 touching)
#   [4/53] outlet=9 (1 pairs, 0 touching)
#   [5/53] outlet=15 (1 pairs, 1 touching)
#   [6/53] outlet=16 (1 pairs, 0 touching)
#   [7/53] outlet=18 (1 pairs, 1 touching)
#   [8/53] outlet=21 (3 pairs, 1 touching)
#   [9/53] outlet=22 (no pairs)
#   [10/53] outlet=23 (1 pairs, 1 touching)
#   [11/53] outlet=24 (1 pairs, 1 touching)
#   [12/53] outlet=25 (no pairs)
#   [13/53] outlet=26 (3 pairs, 1 touching)
#   [14/53] outlet=27 (no pairs)
#   [15/53] outlet=41 (no pairs)
#   [16/53] outlet=48 (1 pairs, 0 touching)
#   [17/53] outlet=75 (no pairs)
#   [18/53] outlet=95 (no pairs)
#   [19/53] outlet=122 (no pairs)
#   [20/53] outlet=180 (no pairs)
#   [21/53] outlet=221 (no pairs)
#   [22/53] outlet=224 (1 pairs, 0 touching)
#   [23/53] outlet=270 (no pairs)
#   [24/53] outlet=318 (no pairs)
#   [25/53] outlet=365 (6 pairs, 2 touching)
#   [26/53] outlet=707 (1 pairs, 0 touching)
#   [27/53] outlet=1173 (no pairs)
#   [28/53] outlet=1615 (1 pairs, 1 touching)
#   [29/53] outlet=2704 (no pairs)
#   [30/53] outlet=2705 (no pairs)
#   [31/53] outlet=2717 (no pairs)
#   [32/53] outlet=2748 (no pairs)
#   [33/53] outlet=2751 (no pairs)
#   [34/53] outlet=2816 (1 pairs, 1 touching)
#   [35/53] outlet=2818 (no pairs)
#   [36/53] outlet=2872 (no pairs)
#   [37/53] outlet=2889 (28 pairs, 5 touching)
#   [38/53] outlet=2891 (no pairs)
#   [39/53] outlet=2893 (3 pairs, 1 touching)
#   [40/53] outlet=2906 (no pairs)
#   [41/53] outlet=2922 (6 pairs, 2 touching)
#   [42/53] outlet=2923 (36 pairs, 5 touching)
#   [43/53] outlet=2934 (no pairs)
#   [44/53] outlet=2935 (no pairs)
#   [45/53] outlet=2937 (no pairs)
#   [46/53] outlet=2938 (15 pairs, 3 touching)
#   [47/53] outlet=2954 (15 pairs, 2 touching)
#   [48/53] outlet=2959 (no pairs)
#   [49/53] outlet=2961 (1 pairs, 1 touching)
#   [50/53] outlet=2981 (1 pairs, 0 touching)
#   [51/53] outlet=3013 (3 pairs, 1 touching)
#   [52/53] outlet=3016 (no pairs)
#   [53/53] outlet=3019 (15 pairs, 3 touching)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/humboldt/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: CALNALPINE
# ================================================================================
#   Using z_th=1700 m, lat=39.69
# Loading calnalpine...
#   DEM shape: (256, 360)
#   Elevation range: 1020 - 2677 m
#   Applied z_th=1700 m mask: 47.4% valid pixels
#   Stream network (threshold=145):
#     Outlets: 47, Heads: 82, Confluences: 35
#
# Running coupling + asymmetry analysis...
#   [1/47] outlet=0 (no pairs)
#   [2/47] outlet=11 (no pairs)
#   [3/47] outlet=100 (no pairs)
#   [4/47] outlet=143 (no pairs)
#   [5/47] outlet=150 (21 pairs, 3 touching)
#   [6/47] outlet=172 (1 pairs, 1 touching)
#   [7/47] outlet=205 (no pairs)
#   [8/47] outlet=242 (no pairs)
#   [9/47] outlet=248 (3 pairs, 0 touching)
#   [10/47] outlet=253 (1 pairs, 1 touching)
#   [11/47] outlet=255 (1 pairs, 1 touching)
#   [12/47] outlet=264 (1 pairs, 1 touching)
#   [13/47] outlet=314 (3 pairs, 1 touching)
#   [14/47] outlet=318 (no pairs)
#   [15/47] outlet=402 (no pairs)
#   [16/47] outlet=430 (no pairs)
#   [17/47] outlet=495 (no pairs)
#   [18/47] outlet=503 (1 pairs, 1 touching)
#   [19/47] outlet=527 (no pairs)
#   [20/47] outlet=546 (no pairs)
#   [21/47] outlet=749 (no pairs)
#   [22/47] outlet=754 (no pairs)
#   [23/47] outlet=755 (6 pairs, 3 touching)
#   [24/47] outlet=814 (no pairs)
#   [25/47] outlet=888 (no pairs)
#   [26/47] outlet=930 (1 pairs, 1 touching)
#   [27/47] outlet=938 (no pairs)
#   [28/47] outlet=954 (1 pairs, 1 touching)
#   [29/47] outlet=959 (15 pairs, 4 touching)
#   [30/47] outlet=960 (no pairs)
#   [31/47] outlet=1001 (no pairs)
#   [32/47] outlet=1040 (no pairs)
#   [33/47] outlet=1064 (no pairs)
#   [34/47] outlet=1128 (3 pairs, 2 touching)
#   [35/47] outlet=1191 (no pairs)
#   [36/47] outlet=1222 (1 pairs, 1 touching)
#   [37/47] outlet=1250 (3 pairs, 1 touching)
#   [38/47] outlet=1256 (no pairs)
#   [39/47] outlet=1286 (no pairs)
#   [40/47] outlet=1353 (no pairs)
#   [41/47] outlet=1403 (no pairs)
#   [42/47] outlet=1436 (1 pairs, 1 touching)
#   [43/47] outlet=1477 (6 pairs, 1 touching)
#   [44/47] outlet=1497 (no pairs)
#   [45/47] outlet=1503 (no pairs)
#   [46/47] outlet=1504 (no pairs)
#   [47/47] outlet=1506 (1 pairs, 0 touching)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/calnalpine/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: DAQING
# ================================================================================
#   Using z_th=1200 m, lat=40.71
# Loading daqing...
#   DEM shape: (157, 349)
#   Elevation range: 1072 - 2293 m
#   Applied z_th=1200 m mask: 85.7% valid pixels
#   Stream network (threshold=145):
#     Outlets: 34, Heads: 76, Confluences: 42
#
# Running coupling + asymmetry analysis...
#   [1/34] outlet=0 (1 pairs, 0 touching)
#   [2/34] outlet=4 (no pairs)
#   [3/34] outlet=50 (45 pairs, 6 touching)
#   [4/34] outlet=87 (no pairs)
#   [5/34] outlet=104 (no pairs)
#   [6/34] outlet=248 (1 pairs, 0 touching)
#   [7/34] outlet=378 (no pairs)
#   [8/34] outlet=507 (no pairs)
#   [9/34] outlet=576 (1 pairs, 1 touching)
#   [10/34] outlet=686 (3 pairs, 0 touching)
#   [11/34] outlet=822 (no pairs)
#   [12/34] outlet=838 (3 pairs, 1 touching)
#   [13/34] outlet=933 (1 pairs, 0 touching)
#   [14/34] outlet=965 (1 pairs, 1 touching)
#   [15/34] outlet=982 (1 pairs, 1 touching)
#   [16/34] outlet=1142 (3 pairs, 0 touching)
#   [17/34] outlet=1149 (6 pairs, 2 touching)
#   [18/34] outlet=1194 (no pairs)
#   [19/34] outlet=1344 (1 pairs, 1 touching)
#   [20/34] outlet=1368 (no pairs)
#   [21/34] outlet=1414 (no pairs)
#   [22/34] outlet=1429 (no pairs)
#   [23/34] outlet=1442 (10 pairs, 3 touching)
#   [24/34] outlet=1518 (no pairs)
#   [25/34] outlet=1556 (no pairs)
#   [26/34] outlet=1606 (no pairs)
#   [27/34] outlet=1693 (28 pairs, 4 touching)
#   [28/34] outlet=1715 (no pairs)
#   [29/34] outlet=1843 (no pairs)
#   [30/34] outlet=1854 (6 pairs, 2 touching)
#   [31/34] outlet=1958 (no pairs)
#   [32/34] outlet=2002 (3 pairs, 0 touching)
#   [33/34] outlet=2210 (no pairs)
#   [34/34] outlet=2254 (1 pairs, 1 touching)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/daqing/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: KAMMANASIE
# ================================================================================
#   Using z_th=630 m, lat=-33.62
# Loading kammanasie...
#   DEM shape: (212, 414)
#   Elevation range: 475 - 1935 m
#   Applied z_th=630 m mask: 85.8% valid pixels
#   Stream network (threshold=145):
#     Outlets: 49, Heads: 133, Confluences: 82
#
# Running coupling + asymmetry analysis...
#   [1/49] outlet=22 (no pairs)
#   [2/49] outlet=145 (15 pairs, 4 touching)
#   [3/49] outlet=187 (1 pairs, 1 touching)
#   [4/49] outlet=251 (1 pairs, 0 touching)
#   [5/49] outlet=274 (10 pairs, 4 touching)
#   [6/49] outlet=295 (1 pairs, 1 touching)
#   [7/49] outlet=384 (15 pairs, 4 touching)
#   [8/49] outlet=450 (3 pairs, 0 touching)
#   [9/49] outlet=464 (no pairs)
#   [10/49] outlet=524 (1 pairs, 1 touching)
#   [11/49] outlet=674 (15 pairs, 3 touching)
#   [12/49] outlet=706 (no pairs)
#   [13/49] outlet=742 (15 pairs, 2 touching)
#   [14/49] outlet=800 (no pairs)
#   [15/49] outlet=833 (1 pairs, 0 touching)
#   [16/49] outlet=898 (1 pairs, 1 touching)
#   [17/49] outlet=908 (no pairs)
#   [18/49] outlet=930 (no pairs)
#   [19/49] outlet=1079 (6 pairs, 1 touching)
#   [20/49] outlet=1140 (6 pairs, 1 touching)
#   [21/49] outlet=1156 (no pairs)
#   [22/49] outlet=1192 (1 pairs, 1 touching)
#   [23/49] outlet=1250 (36 pairs, 4 touching)
#   [24/49] outlet=1314 (1 pairs, 1 touching)
#   [25/49] outlet=1335 (no pairs)
#   [26/49] outlet=1482 (1 pairs, 0 touching)
#   [27/49] outlet=1546 (3 pairs, 2 touching)
#   [28/49] outlet=1625 (6 pairs, 2 touching)
#   [29/49] outlet=1753 (15 pairs, 3 touching)
#   [30/49] outlet=1935 (no pairs)
#   [31/49] outlet=1971 (no pairs)
#   [32/49] outlet=1972 (1 pairs, 0 touching)
#   [33/49] outlet=1973 (28 pairs, 4 touching)
#   [34/49] outlet=2080 (1 pairs, 1 touching)
#   [35/49] outlet=2151 (no pairs)
#   [36/49] outlet=2164 (no pairs)
#   [37/49] outlet=2201 (no pairs)
#   [38/49] outlet=2256 (no pairs)
#   [39/49] outlet=2310 (3 pairs, 1 touching)
#   [40/49] outlet=2359 (3 pairs, 1 touching)
#   [41/49] outlet=2417 (no pairs)
#   [42/49] outlet=2490 (no pairs)
#   [43/49] outlet=2647 (6 pairs, 1 touching)
#   [44/49] outlet=2745 (no pairs)
#   [45/49] outlet=2759 (28 pairs, 3 touching)
#   [46/49] outlet=2810 (no pairs)
#   [47/49] outlet=2812 (1 pairs, 1 touching)
#   [48/49] outlet=2813 (no pairs)
#   [49/49] outlet=2817 (1 pairs, 1 touching)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/kammanasie/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: LULIANG
# ================================================================================
#   Using z_th=1100 m, lat=39.27
# Loading luliang...
#   DEM shape: (349, 756)
#   Elevation range: 857 - 2397 m
#   Applied z_th=1100 m mask: 55.8% valid pixels
#   Stream network (threshold=145):
#     Outlets: 113, Heads: 291, Confluences: 177
#
# Running coupling + asymmetry analysis...
#   [1/113] outlet=0 (no pairs)
#   [2/113] outlet=7 (no pairs)
#   [3/113] outlet=8 (no pairs)
#   [4/113] outlet=14 (6 pairs, 1 touching)
#   [5/113] outlet=75 (1 pairs, 1 touching)
#   [6/113] outlet=106 (no pairs)
#   [7/113] outlet=134 (no pairs)
#   [8/113] outlet=189 (1 pairs, 0 touching)
#   [9/113] outlet=215 (no pairs)
#   [10/113] outlet=224 (1 pairs, 1 touching)
#   [11/113] outlet=252 (no pairs)
#   [12/113] outlet=279 (no pairs)
#   [13/113] outlet=339 (no pairs)
#   [14/113] outlet=392 (6 pairs, 2 touching)
#   [15/113] outlet=444 (1 pairs, 1 touching)
#   [16/113] outlet=505 (no pairs)
#   [17/113] outlet=523 (no pairs)
#   [18/113] outlet=574 (no pairs)
#   [19/113] outlet=630 (3 pairs, 2 touching)
#   [20/113] outlet=738 (no pairs)
#   [21/113] outlet=745 (no pairs)
#   [22/113] outlet=751 (no pairs)
#   [23/113] outlet=772 (no pairs)
#   [24/113] outlet=880 (231 pairs, 15 touching)
#   [25/113] outlet=904 (no pairs)
#   [26/113] outlet=1025 (no pairs)
#   [27/113] outlet=1092 (no pairs)
#   [28/113] outlet=1141 (no pairs)
#   [29/113] outlet=1277 (no pairs)
#   [30/113] outlet=1318 (36 pairs, 4 touching)
#   [31/113] outlet=1331 (no pairs)
#   [32/113] outlet=1454 (no pairs)
#   [33/113] outlet=1483 (no pairs)
#   [34/113] outlet=1488 (no pairs)
#   [35/113] outlet=1599 (no pairs)
#   [36/113] outlet=1639 (3 pairs, 0 touching)
#   [37/113] outlet=1658 (no pairs)
#   [38/113] outlet=1699 (1 pairs, 1 touching)
#   [39/113] outlet=1865 (1 pairs, 1 touching)
#   [40/113] outlet=1879 (no pairs)
#   [41/113] outlet=1933 (1 pairs, 1 touching)
#   [42/113] outlet=2116 (no pairs)
#   [43/113] outlet=2117 (no pairs)
#   [44/113] outlet=2140 (36 pairs, 5 touching)
#   [45/113] outlet=2172 (1 pairs, 0 touching)
#   [46/113] outlet=2217 (253 pairs, 15 touching)
#   [47/113] outlet=2293 (no pairs)
#   [48/113] outlet=2302 (no pairs)
#   [49/113] outlet=2427 (no pairs)
#   [50/113] outlet=2446 (28 pairs, 6 touching)
#   [51/113] outlet=2577 (6 pairs, 2 touching)
#   [52/113] outlet=2622 (no pairs)
#   [53/113] outlet=2703 (no pairs)
#   [54/113] outlet=2720 (no pairs)
#   [55/113] outlet=2761 (no pairs)
#   [56/113] outlet=2811 (no pairs)
#   [57/113] outlet=2853 (no pairs)
#   [58/113] outlet=2952 (no pairs)
#   [59/113] outlet=3031 (no pairs)
#   [60/113] outlet=3083 (no pairs)
#   [61/113] outlet=3099 (no pairs)
#   [62/113] outlet=3237 (no pairs)
#   [63/113] outlet=3282 (no pairs)
#   [64/113] outlet=3337 (10 pairs, 3 touching)
#   [65/113] outlet=3356 (21 pairs, 5 touching)
#   [66/113] outlet=3407 (no pairs)
#   [67/113] outlet=3478 (1 pairs, 1 touching)
#   [68/113] outlet=3615 (no pairs)
#   [69/113] outlet=3733 (no pairs)
#   [70/113] outlet=3765 (1 pairs, 1 touching)
#   [71/113] outlet=3878 (no pairs)
#   [72/113] outlet=3922 (no pairs)
#   [73/113] outlet=3990 (no pairs)
#   [74/113] outlet=4060 (66 pairs, 8 touching)
#   [75/113] outlet=4100 (10 pairs, 2 touching)
#   [76/113] outlet=4314 (45 pairs, 5 touching)
#   [77/113] outlet=4340 (no pairs)
#   [78/113] outlet=4396 (no pairs)
#   [79/113] outlet=4440 (no pairs)
#   [80/113] outlet=4504 (no pairs)
#   [81/113] outlet=4549 (no pairs)
#   [82/113] outlet=4718 (21 pairs, 6 touching)
#   [83/113] outlet=4755 (no pairs)
#   [84/113] outlet=4785 (no pairs)
#   [85/113] outlet=4912 (55 pairs, 6 touching)
#   [86/113] outlet=4913 (136 pairs, 10 touching)
#   [87/113] outlet=5317 (no pairs)
#   [88/113] outlet=5342 (no pairs)
#   [89/113] outlet=5416 (no pairs)
#   [90/113] outlet=5448 (1 pairs, 1 touching)
#   [91/113] outlet=5549 (no pairs)
#   [92/113] outlet=5600 (no pairs)
#   [93/113] outlet=5617 (3 pairs, 2 touching)
#   [94/113] outlet=5753 (no pairs)
#   [95/113] outlet=5760 (1 pairs, 1 touching)
#   [96/113] outlet=5886 (no pairs)
#   [97/113] outlet=5944 (1 pairs, 1 touching)
#   [98/113] outlet=5971 (105 pairs, 8 touching)
#   [99/113] outlet=5997 (no pairs)
#   [100/113] outlet=6038 (no pairs)
#   [101/113] outlet=6083 (no pairs)
#   [102/113] outlet=6093 (no pairs)
#   [103/113] outlet=6175 (no pairs)
#   [104/113] outlet=6186 (1 pairs, 0 touching)
#   [105/113] outlet=6289 (no pairs)
#   [106/113] outlet=6311 (no pairs)
#   [107/113] outlet=6436 (3 pairs, 1 touching)
#   [108/113] outlet=6497 (no pairs)
#   [109/113] outlet=6516 (no pairs)
#   [110/113] outlet=6519 (no pairs)
#   [111/113] outlet=6521 (no pairs)
#   [112/113] outlet=6522 (1 pairs, 1 touching)
#   [113/113] outlet=6523 (no pairs)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/luliang/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: FINISTERRE
# ================================================================================
#   Using z_th=400 m, lat=-5.95
# Loading finisterre...
#   DEM shape: (1441, 1985)
#   Elevation range: 0 - 4096 m
#   Applied z_th=400 m mask: 60.5% valid pixels
#   Stream network (threshold=145):
#     Outlets: 440, Heads: 3154, Confluences: 2677
#
# Running coupling + asymmetry analysis...
#   [1/440] outlet=1 (1 pairs, 1 touching)
#   [2/440] outlet=6 (1 pairs, 1 touching)
#   [3/440] outlet=7 (105 pairs, 7 touching)
#   [4/440] outlet=8 (no pairs)
#   [5/440] outlet=9 (351 pairs, 16 touching)
#   [6/440] outlet=10 (no pairs)
#   [7/440] outlet=22 (no pairs)
#   [8/440] outlet=24 (10 pairs, 2 touching)
#   [9/440] outlet=25 (no pairs)
#   [10/440] outlet=26 (no pairs)
#   [11/440] outlet=30 (no pairs)
#   [12/440] outlet=31 (no pairs)
#   [13/440] outlet=33 (no pairs)
#   [14/440] outlet=34 (3 pairs, 2 touching)
#   [15/440] outlet=35 (no pairs)
#   [16/440] outlet=36 (1 pairs, 0 touching)
#   [17/440] outlet=37 (1 pairs, 0 touching)
#   [18/440] outlet=38 (1 pairs, 1 touching)
#   [19/440] outlet=39 (10 pairs, 1 touching)
#   [20/440] outlet=40 (no pairs)
#   [21/440] outlet=41 (1 pairs, 1 touching)
#   [22/440] outlet=42 (no pairs)
#   [23/440] outlet=43 (no pairs)
#   [24/440] outlet=44 (10 pairs, 3 touching)
#   [25/440] outlet=45 (28 pairs, 4 touching)
#   [26/440] outlet=66 (6 pairs, 1 touching)
#   [27/440] outlet=67 (2926 pairs, 56 touching)
#   [28/440] outlet=230 (1 pairs, 1 touching)
#   [29/440] outlet=302 (no pairs)
#   [30/440] outlet=692 (36 pairs, 3 touching)
#   [31/440] outlet=955 (153 pairs, 9 touching)
#   [32/440] outlet=984 (no pairs)
#   [33/440] outlet=985 (3 pairs, 1 touching)
#   [34/440] outlet=1222 (no pairs)
#   [35/440] outlet=1639 (21 pairs, 2 touching)
#   [36/440] outlet=1837 (1 pairs, 0 touching)
#   [37/440] outlet=1858 (3 pairs, 2 touching)
#   [38/440] outlet=1978 (no pairs)
#   [39/440] outlet=1980 (1 pairs, 0 touching)
#   [40/440] outlet=1981 (1 pairs, 1 touching)
#   [41/440] outlet=2101 (4560 pairs, 84 touching)
#   [42/440] outlet=2126 (no pairs)
#   [43/440] outlet=2229 (no pairs)
#   [44/440] outlet=2356 (no pairs)
#   [45/440] outlet=2549 (11476 pairs, 130 touching)
#   [46/440] outlet=3289 (no pairs)
#   [47/440] outlet=4682 (1 pairs, 1 touching)
#   [48/440] outlet=4765 (no pairs)
#   [49/440] outlet=5202 (no pairs)
#   [50/440] outlet=5262 (171 pairs, 9 touching)
#   [51/440] outlet=6691 (no pairs)
#   [52/440] outlet=7271 (no pairs)
#   [53/440] outlet=7757 (no pairs)
#   [54/440] outlet=8152 (no pairs)
#   [55/440] outlet=8338 (1 pairs, 1 touching)
#   [56/440] outlet=8389 (21 pairs, 3 touching)
#   [57/440] outlet=10557 (36 pairs, 3 touching)
#   [58/440] outlet=11989 (no pairs)
#   [59/440] outlet=11990 (no pairs)
#   [60/440] outlet=12241 (no pairs)
#   [61/440] outlet=13288 (1 pairs, 0 touching)
#   [62/440] outlet=14161 (no pairs)
#   [63/440] outlet=14168 (741 pairs, 36 touching)
#   [64/440] outlet=14781 (105 pairs, 9 touching)
#   [65/440] outlet=14827 (1 pairs, 1 touching)
#   [66/440] outlet=14947 (1 pairs, 0 touching)
#   [67/440] outlet=15094 (no pairs)
#   [68/440] outlet=15497 (no pairs)
#   [69/440] outlet=15867 (no pairs)
#   [70/440] outlet=15931 (no pairs)
#   [71/440] outlet=16155 (28 pairs, 6 touching)
#   [72/440] outlet=16889 (1 pairs, 1 touching)
#   [73/440] outlet=17005 (3 pairs, 1 touching)
#   [74/440] outlet=17255 (10 pairs, 2 touching)
#   [75/440] outlet=17312 (36 pairs, 3 touching)
#   [76/440] outlet=17530 (1 pairs, 0 touching)
#   [77/440] outlet=17548 (1 pairs, 0 touching)
#   [78/440] outlet=18002 (1 pairs, 1 touching)
#   [79/440] outlet=18390 (no pairs)
#   [80/440] outlet=18450 (no pairs)
#   [81/440] outlet=18515 (378 pairs, 20 touching)
#   [82/440] outlet=18939 (no pairs)
#   [83/440] outlet=19135 (10 pairs, 1 touching)
#   [84/440] outlet=19261 (3 pairs, 0 touching)
#   [85/440] outlet=19361 (no pairs)
#   [86/440] outlet=19557 (no pairs)
#   [87/440] outlet=19793 (no pairs)
#   [88/440] outlet=20071 (1 pairs, 0 touching)
#   [89/440] outlet=20155 (no pairs)
#   [90/440] outlet=20158 (15 pairs, 3 touching)
#   [91/440] outlet=20554 (1 pairs, 1 touching)
#   [92/440] outlet=20597 (1 pairs, 0 touching)
#   [93/440] outlet=20794 (no pairs)
#   [94/440] outlet=20922 (no pairs)
#   [95/440] outlet=20924 (no pairs)
#   [96/440] outlet=20997 (no pairs)
#   [97/440] outlet=21049 (1 pairs, 1 touching)
#   [98/440] outlet=21067 (990 pairs, 34 touching)
#   [99/440] outlet=21168 (1 pairs, 0 touching)
#   [100/440] outlet=21396 (105 pairs, 13 touching)
#   [101/440] outlet=21721 (1 pairs, 1 touching)
#   [102/440] outlet=21749 (21 pairs, 2 touching)
#   [103/440] outlet=21790 (1 pairs, 0 touching)
#   [104/440] outlet=21824 (no pairs)
#   [105/440] outlet=21831 (no pairs)
#   [106/440] outlet=21888 (no pairs)
#   [107/440] outlet=21958 (no pairs)
#   [108/440] outlet=22056 (11175 pairs, 151 touching)
#   [109/440] outlet=22152 (no pairs)
#   [110/440] outlet=22153 (2415 pairs, 55 touching)
#   [111/440] outlet=22201 (no pairs)
#   [112/440] outlet=22246 (3 pairs, 2 touching)
#   [113/440] outlet=22324 (no pairs)
#   [114/440] outlet=22394 (no pairs)
#   [115/440] outlet=22395 (no pairs)
#   [116/440] outlet=22422 (no pairs)
#   [117/440] outlet=22553 (no pairs)
#   [118/440] outlet=22587 (no pairs)
#   [119/440] outlet=22683 (no pairs)
#   [120/440] outlet=22884 (45 pairs, 6 touching)
#   [121/440] outlet=22947 (300 pairs, 18 touching)
#   [122/440] outlet=23073 (21 pairs, 2 touching)
#   [123/440] outlet=23075 (no pairs)
#   [124/440] outlet=23256 (10 pairs, 1 touching)
#   [125/440] outlet=23565 (no pairs)
#   [126/440] outlet=23566 (3 pairs, 2 touching)
#   [127/440] outlet=23956 (3 pairs, 1 touching)
#   [128/440] outlet=24101 (6 pairs, 1 touching)
#   [129/440] outlet=24140 (no pairs)
#   [130/440] outlet=24443 (no pairs)
#   [131/440] outlet=24708 (351 pairs, 16 touching)
#   [132/440] outlet=24795 (10 pairs, 2 touching)
#   [133/440] outlet=24833 (no pairs)
#   [134/440] outlet=24835 (no pairs)
#   [135/440] outlet=24910 (1 pairs, 0 touching)
#   [136/440] outlet=25123 (6 pairs, 3 touching)
#   [137/440] outlet=25173 (no pairs)
#   [138/440] outlet=25216 (1 pairs, 1 touching)
#   [139/440] outlet=25383 (no pairs)
#   [140/440] outlet=25384 (no pairs)
#   [141/440] outlet=25691 (no pairs)
#   [142/440] outlet=25787 (no pairs)
#   [143/440] outlet=25835 (no pairs)
#   [144/440] outlet=25981 (no pairs)
#   [145/440] outlet=26402 (no pairs)
#   [146/440] outlet=26760 (no pairs)
#   [147/440] outlet=26862 (no pairs)
#   [148/440] outlet=26868 (1540 pairs, 52 touching)
#   [149/440] outlet=26909 (no pairs)
#   [150/440] outlet=26946 (no pairs)
#   [151/440] outlet=27602 (no pairs)
#   [152/440] outlet=27803 (1 pairs, 0 touching)
#   [153/440] outlet=27929 (no pairs)
#   [154/440] outlet=28130 (no pairs)
#   [155/440] outlet=28503 (no pairs)
#   [156/440] outlet=28686 (3 pairs, 0 touching)
#   [157/440] outlet=28760 (3 pairs, 0 touching)
#   [158/440] outlet=29641 (36 pairs, 3 touching)
#   [159/440] outlet=29715 (no pairs)
#   [160/440] outlet=29750 (1 pairs, 1 touching)
#   [161/440] outlet=29897 (1 pairs, 1 touching)
#   [162/440] outlet=30028 (no pairs)
#   [163/440] outlet=30060 (10 pairs, 2 touching)
#   [164/440] outlet=30211 (1 pairs, 0 touching)
#   [165/440] outlet=30290 (no pairs)
#   [166/440] outlet=30424 (no pairs)
#   [167/440] outlet=30425 (6 pairs, 2 touching)
#   [168/440] outlet=30503 (4465 pairs, 88 touching)
#   [169/440] outlet=30839 (no pairs)
#   [170/440] outlet=31208 (no pairs)
#   [171/440] outlet=31209 (no pairs)
#   [172/440] outlet=31261 (1 pairs, 0 touching)
#   [173/440] outlet=31463 (no pairs)
#   [174/440] outlet=31766 (no pairs)
#   [175/440] outlet=31845 (no pairs)
#   [176/440] outlet=32393 (3 pairs, 1 touching)
#   [177/440] outlet=32397 (no pairs)
#   [178/440] outlet=32437 (no pairs)
#   [179/440] outlet=32469 (no pairs)
#   [180/440] outlet=32498 (no pairs)
#   [181/440] outlet=32638 (no pairs)
#   [182/440] outlet=32677 (no pairs)
#   [183/440] outlet=32797 (10 pairs, 3 touching)
#   [184/440] outlet=32953 (no pairs)
#   [185/440] outlet=33043 (no pairs)
#   [186/440] outlet=33308 (1 pairs, 1 touching)
#   [187/440] outlet=33465 (13695 pairs, 165 touching)
#   [188/440] outlet=34060 (15 pairs, 2 touching)
#   [189/440] outlet=34142 (3 pairs, 1 touching)
#   [190/440] outlet=34676 (no pairs)
#   [191/440] outlet=34830 (3 pairs, 1 touching)
#   [192/440] outlet=34951 (no pairs)
#   [193/440] outlet=35657 (no pairs)
#   [194/440] outlet=35660 (1 pairs, 0 touching)
#   [195/440] outlet=35694 (no pairs)
#   [196/440] outlet=35731 (1 pairs, 1 touching)
#   [197/440] outlet=35881 (no pairs)
#   [198/440] outlet=35999 (no pairs)
#   [199/440] outlet=36032 (10 pairs, 2 touching)
#   [200/440] outlet=36163 (no pairs)
#   [201/440] outlet=36380 (no pairs)
#   [202/440] outlet=36444 (1 pairs, 0 touching)
#   [203/440] outlet=36769 (no pairs)
#   [204/440] outlet=36902 (no pairs)
#   [205/440] outlet=36977 (no pairs)
#   [206/440] outlet=37007 (10 pairs, 2 touching)
#   [207/440] outlet=37403 (1 pairs, 1 touching)
#   [208/440] outlet=37672 (903 pairs, 33 touching)
#   [209/440] outlet=38056 (no pairs)
#   [210/440] outlet=38058 (no pairs)
#   [211/440] outlet=38327 (36 pairs, 2 touching)
#   [212/440] outlet=38518 (no pairs)
#   [213/440] outlet=38558 (no pairs)
#   [214/440] outlet=38750 (1 pairs, 0 touching)
#   [215/440] outlet=39227 (1 pairs, 0 touching)
#   [216/440] outlet=39506 (no pairs)
#   [217/440] outlet=39837 (1 pairs, 1 touching)
#   [218/440] outlet=40274 (6 pairs, 1 touching)
#   [219/440] outlet=40451 (no pairs)
#   [220/440] outlet=40722 (no pairs)
#   [221/440] outlet=40997 (no pairs)
#   [222/440] outlet=41259 (1275 pairs, 31 touching)
#   [223/440] outlet=41522 (3 pairs, 2 touching)
#   [224/440] outlet=41683 (6 pairs, 1 touching)
#   [225/440] outlet=41757 (no pairs)
#   [226/440] outlet=41808 (1 pairs, 0 touching)
#   [227/440] outlet=42065 (2346 pairs, 55 touching)
#   [228/440] outlet=42396 (406 pairs, 20 touching)
#   [229/440] outlet=42482 (no pairs)
#   [230/440] outlet=42540 (no pairs)
#   [231/440] outlet=42598 (no pairs)
#   [232/440] outlet=42696 (no pairs)
#   [233/440] outlet=42846 (no pairs)
#   [234/440] outlet=42888 (no pairs)
#   [235/440] outlet=42890 (no pairs)
#   [236/440] outlet=43145 (no pairs)
#   [237/440] outlet=43208 (no pairs)
#   [238/440] outlet=43250 (no pairs)
#   [239/440] outlet=43647 (no pairs)
#   [240/440] outlet=43722 (1 pairs, 0 touching)
#   [241/440] outlet=43794 (1 pairs, 1 touching)
#   [242/440] outlet=44051 (no pairs)
#   [243/440] outlet=44436 (1 pairs, 1 touching)
#   [244/440] outlet=44474 (no pairs)
#   [245/440] outlet=44475 (15 pairs, 3 touching)
#   [246/440] outlet=44518 (no pairs)
#   [247/440] outlet=45076 (no pairs)
#   [248/440] outlet=45194 (3 pairs, 0 touching)
#   [249/440] outlet=45343 (no pairs)
#   [250/440] outlet=45568 (no pairs)
#   [251/440] outlet=45831 (no pairs)
#   [252/440] outlet=45867 (15 pairs, 2 touching)
#   [253/440] outlet=45892 (91 pairs, 11 touching)
#   [254/440] outlet=45954 (no pairs)
#   [255/440] outlet=45971 (1 pairs, 1 touching)
#   [256/440] outlet=45972 (1 pairs, 1 touching)
#   [257/440] outlet=46019 (19110 pairs, 167 touching)
#   [258/440] outlet=46061 (no pairs)
#   [259/440] outlet=46125 (no pairs)
#   [260/440] outlet=46150 (no pairs)
#   [261/440] outlet=46194 (no pairs)
#   [262/440] outlet=46503 (10 pairs, 3 touching)
#   [263/440] outlet=46536 (no pairs)
#   [264/440] outlet=46537 (no pairs)
#   [265/440] outlet=47072 (no pairs)
#   [266/440] outlet=47326 (1 pairs, 1 touching)
#   [267/440] outlet=48020 (no pairs)
#   [268/440] outlet=48316 (no pairs)
#   [269/440] outlet=48392 (no pairs)
#   [270/440] outlet=48427 (no pairs)
#   [271/440] outlet=48947 (no pairs)
#   [272/440] outlet=49113 (28 pairs, 5 touching)
#   [273/440] outlet=49234 (3916 pairs, 86 touching)
#   [274/440] outlet=49421 (no pairs)
#   [275/440] outlet=49579 (1 pairs, 0 touching)
#   [276/440] outlet=49732 (no pairs)
#   [277/440] outlet=49815 (no pairs)
#   [278/440] outlet=50215 (1 pairs, 0 touching)
#   [279/440] outlet=50243 (1 pairs, 1 touching)
#   [280/440] outlet=50245 (no pairs)
#   [281/440] outlet=50492 (no pairs)
#   [282/440] outlet=50776 (6105 pairs, 101 touching)
#   [283/440] outlet=50865 (no pairs)
#   [284/440] outlet=50887 (6 pairs, 1 touching)
#   [285/440] outlet=50917 (120 pairs, 14 touching)
#   [286/440] outlet=51065 (no pairs)
#   [287/440] outlet=51167 (no pairs)
#   [288/440] outlet=51226 (no pairs)
#   [289/440] outlet=51385 (no pairs)
#   [290/440] outlet=51423 (1 pairs, 1 touching)
#   [291/440] outlet=52220 (no pairs)
#   [292/440] outlet=52573 (no pairs)
#   [293/440] outlet=52693 (105 pairs, 5 touching)
#   [294/440] outlet=52730 (no pairs)
#   [295/440] outlet=52777 (no pairs)
#   [296/440] outlet=52922 (no pairs)
#   [297/440] outlet=53383 (no pairs)
#   [298/440] outlet=53384 (no pairs)
#   [299/440] outlet=53564 (21 pairs, 3 touching)
#   [300/440] outlet=53613 (no pairs)
#   [301/440] outlet=53737 (no pairs)
#   [302/440] outlet=53825 (no pairs)
#   [303/440] outlet=54035 (no pairs)
#   [304/440] outlet=54221 (1 pairs, 1 touching)
#   [305/440] outlet=55004 (946 pairs, 28 touching)
#   [306/440] outlet=55005 (no pairs)
#   [307/440] outlet=55128 (6 pairs, 2 touching)
#   [308/440] outlet=55130 (no pairs)
#   [309/440] outlet=55192 (no pairs)
#   [310/440] outlet=55224 (3160 pairs, 63 touching)
#   [311/440] outlet=55258 (no pairs)
#   [312/440] outlet=55300 (no pairs)
#   [313/440] outlet=55356 (no pairs)
#   [314/440] outlet=55430 (3 pairs, 0 touching)
#   [315/440] outlet=55882 (3 pairs, 1 touching)
#   [316/440] outlet=56398 (1 pairs, 1 touching)
#   [317/440] outlet=56507 (1 pairs, 1 touching)
#   [318/440] outlet=56619 (1 pairs, 0 touching)
#   [319/440] outlet=57010 (1 pairs, 1 touching)
#   [320/440] outlet=57435 (no pairs)
#   [321/440] outlet=57742 (no pairs)
#   [322/440] outlet=57743 (no pairs)
#   [323/440] outlet=57768 (45 pairs, 9 touching)
#   [324/440] outlet=57937 (10 pairs, 4 touching)
#   [325/440] outlet=59049 (10 pairs, 3 touching)
#   [326/440] outlet=59247 (no pairs)
#   [327/440] outlet=59518 (no pairs)
#   [328/440] outlet=59757 (no pairs)
#   [329/440] outlet=60135 (no pairs)
#   [330/440] outlet=60361 (595 pairs, 25 touching)
#   [331/440] outlet=60390 (no pairs)
#   [332/440] outlet=60391 (no pairs)
#   [333/440] outlet=60573 (no pairs)
#   [334/440] outlet=60802 (no pairs)
#   [335/440] outlet=60803 (no pairs)
#   [336/440] outlet=60967 (6 pairs, 1 touching)
#   [337/440] outlet=61045 (no pairs)
#   [338/440] outlet=61142 (no pairs)
#   [339/440] outlet=61224 (no pairs)
#   [340/440] outlet=61436 (136 pairs, 10 touching)
#   [341/440] outlet=61924 (no pairs)
#   [342/440] outlet=62210 (1 pairs, 0 touching)
#   [343/440] outlet=62615 (1 pairs, 1 touching)
#   [344/440] outlet=62668 (no pairs)
#   [345/440] outlet=62688 (no pairs)
#   [346/440] outlet=62752 (no pairs)
#   [347/440] outlet=62815 (66 pairs, 8 touching)
#   [348/440] outlet=63071 (no pairs)
#   [349/440] outlet=63497 (10 pairs, 3 touching)
#   [350/440] outlet=63666 (no pairs)
#   [351/440] outlet=63707 (no pairs)
#   [352/440] outlet=63964 (no pairs)
#   [353/440] outlet=64044 (no pairs)
#   [354/440] outlet=64078 (no pairs)
#   [355/440] outlet=64105 (no pairs)
#   [356/440] outlet=64193 (6 pairs, 3 touching)
#   [357/440] outlet=64559 (3081 pairs, 62 touching)
#   [358/440] outlet=64914 (15 pairs, 4 touching)
#   [359/440] outlet=65108 (no pairs)
#   [360/440] outlet=65250 (1 pairs, 1 touching)
#   [361/440] outlet=65348 (no pairs)
#   [362/440] outlet=65350 (no pairs)
#   [363/440] outlet=65465 (no pairs)
#   [364/440] outlet=65466 (no pairs)
#   [365/440] outlet=65488 (no pairs)
#   [366/440] outlet=65628 (no pairs)
#   [367/440] outlet=65666 (1 pairs, 1 touching)
#   [368/440] outlet=65667 (378 pairs, 18 touching)
#   [369/440] outlet=65690 (no pairs)
#   [370/440] outlet=65777 (no pairs)
#   [371/440] outlet=65980 (no pairs)
#   [372/440] outlet=66768 (no pairs)
#   [373/440] outlet=67016 (no pairs)
#   [374/440] outlet=67102 (1 pairs, 1 touching)
#   [375/440] outlet=67157 (55 pairs, 3 touching)
#   [376/440] outlet=67688 (no pairs)
#   [377/440] outlet=67985 (6 pairs, 3 touching)
#   [378/440] outlet=68472 (no pairs)
#   [379/440] outlet=68474 (no pairs)
#   [380/440] outlet=68594 (no pairs)
#   [381/440] outlet=68683 (78 pairs, 10 touching)
#   [382/440] outlet=68733 (21 pairs, 4 touching)
#   [383/440] outlet=69118 (no pairs)
#   [384/440] outlet=69119 (21 pairs, 4 touching)
#   [385/440] outlet=69706 (no pairs)
#   [386/440] outlet=69815 (no pairs)
#   [387/440] outlet=70010 (no pairs)
#   [388/440] outlet=70466 (no pairs)
#   [389/440] outlet=70760 (3 pairs, 0 touching)
#   [390/440] outlet=71558 (55 pairs, 3 touching)
#   [391/440] outlet=71597 (3 pairs, 2 touching)
#   [392/440] outlet=71628 (no pairs)
#   [393/440] outlet=71699 (no pairs)
#   [394/440] outlet=72015 (no pairs)
#   [395/440] outlet=72214 (66 pairs, 6 touching)
#   [396/440] outlet=72580 (3916 pairs, 75 touching)
#   [397/440] outlet=72689 (3 pairs, 2 touching)
#   [398/440] outlet=72690 (66 pairs, 8 touching)
#   [399/440] outlet=72726 (no pairs)
#   [400/440] outlet=72805 (no pairs)
#   [401/440] outlet=73093 (no pairs)
#   [402/440] outlet=73283 (3 pairs, 0 touching)
#   [403/440] outlet=73346 (no pairs)
#   [404/440] outlet=73403 (1 pairs, 0 touching)
#   [405/440] outlet=73622 (no pairs)
#   [406/440] outlet=73922 (1 pairs, 0 touching)
#   [407/440] outlet=73929 (6 pairs, 3 touching)
#   [408/440] outlet=74290 (no pairs)
#   [409/440] outlet=74291 (no pairs)
#   [410/440] outlet=74296 (no pairs)
#   [411/440] outlet=74564 (3 pairs, 1 touching)
#   [412/440] outlet=74834 (no pairs)
#   [413/440] outlet=74902 (21 pairs, 2 touching)
#   [414/440] outlet=74956 (no pairs)
#   [415/440] outlet=75179 (no pairs)
#   [416/440] outlet=75285 (no pairs)
#   [417/440] outlet=75316 (no pairs)
#   [418/440] outlet=75338 (no pairs)
#   [419/440] outlet=75363 (no pairs)
#   [420/440] outlet=75577 (78 pairs, 7 touching)
#   [421/440] outlet=75621 (no pairs)
#   [422/440] outlet=75672 (1081 pairs, 28 touching)
#   [423/440] outlet=75723 (no pairs)
#   [424/440] outlet=75795 (1 pairs, 1 touching)
#   [425/440] outlet=75825 (1 pairs, 1 touching)
#   [426/440] outlet=75878 (no pairs)
#   [427/440] outlet=76079 (1 pairs, 0 touching)
#   [428/440] outlet=76080 (15 pairs, 2 touching)
#   [429/440] outlet=76086 (1 pairs, 1 touching)
#   [430/440] outlet=76105 (3 pairs, 0 touching)
#   [431/440] outlet=76109 (no pairs)
#   [432/440] outlet=76110 (no pairs)
#   [433/440] outlet=76111 (6 pairs, 2 touching)
#   [434/440] outlet=76112 (no pairs)
#   [435/440] outlet=76114 (153 pairs, 16 touching)
#   [436/440] outlet=76115 (no pairs)
#   [437/440] outlet=76116 (3 pairs, 2 touching)
#   [438/440] outlet=76118 (4851 pairs, 68 touching)
#   [439/440] outlet=76125 (no pairs)
#   [440/440] outlet=76128 (no pairs)
#
# Saved results to: /Users/guypi/Projects/channel-heads/data/outputs/finisterre/coupling_asymmetry_results.csv
#
# ================================================================================
# Processing: TAIWAN
# ================================================================================
#   Using z_th=80 m, lat=23.47
# Loading taiwan...
#   DEM shape: (4732, 2100)
#   Elevation range: -45 - 3917 m
#   Applied z_th=80 m mask: 33.1% valid pixels
#   Stream network (threshold=145):
#     Outlets: 793, Heads: 5791, Confluences: 4954
#
# Running coupling + asymmetry analysis...
#   [1/793] outlet=0 (no pairs)
#   [2/793] outlet=2 (no pairs)
#   [3/793] outlet=5 (no pairs)
#   [4/793] outlet=15 (no pairs)
#   [5/793] outlet=23 (no pairs)
#   [6/793] outlet=25 (no pairs)
#   [7/793] outlet=28 (no pairs)
#   [8/793] outlet=45 (no pairs)
#   [9/793] outlet=66 (no pairs)
#   [10/793] outlet=68 (no pairs)
#   [11/793] outlet=77 (1 pairs, 1 touching)
#   [12/793] outlet=87 (no pairs)
#   [13/793] outlet=90 (no pairs)
#   [14/793] outlet=93 (no pairs)
#   [15/793] outlet=97 (no pairs)
#   [16/793] outlet=127 (1 pairs, 1 touching)
#   [17/793] outlet=138 (no pairs)
#   [18/793] outlet=155 (no pairs)
#   [19/793] outlet=158 (no pairs)
#   [20/793] outlet=163 (no pairs)
#   [21/793] outlet=177 (no pairs)
#   [22/793] outlet=178 (no pairs)
#   [23/793] outlet=192 (no pairs)
#   [24/793] outlet=193 (no pairs)
#   [25/793] outlet=210 (no pairs)
#   [26/793] outlet=218 (no pairs)
#   [27/793] outlet=219 (no pairs)
#   [28/793] outlet=228 (no pairs)
#   [29/793] outlet=232 (no pairs)
#   [30/793] outlet=237 (1 pairs, 1 touching)
#   [31/793] outlet=246 (no pairs)
#   [32/793] outlet=252 (no pairs)
#   [33/793] outlet=270 (no pairs)
#   [34/793] outlet=284 (1 pairs, 0 touching)
#   [35/793] outlet=295 (no pairs)
#   [36/793] outlet=310 (no pairs)
#   [37/793] outlet=315 (6 pairs, 2 touching)
#   [38/793] outlet=337 (15 pairs, 5 touching)
#   [39/793] outlet=379 (1 pairs, 0 touching)
#   [40/793] outlet=411 (1 pairs, 1 touching)
#   [41/793] outlet=426 (no pairs)
#   [42/793] outlet=468 (1 pairs, 1 touching)
#   [43/793] outlet=470 (no pairs)
#   [44/793] outlet=471 (no pairs)
#   [45/793] outlet=495 (no pairs)
#   [46/793] outlet=523 (no pairs)
#   [47/793] outlet=540 (21 pairs, 4 touching)
#   [48/793] outlet=590 (no pairs)
#   [49/793] outlet=640 (no pairs)
#   [50/793] outlet=655 (no pairs)
#   [51/793] outlet=721 (no pairs)
#   [52/793] outlet=736 (no pairs)
#   [53/793] outlet=737 (no pairs)
#   [54/793] outlet=768 (15 pairs, 2 touching)
#   [55/793] outlet=770 (6 pairs, 1 touching)
#   [56/793] outlet=780 (no pairs)
#   [57/793] outlet=793 (6 pairs, 3 touching)
#   [58/793] outlet=830 (no pairs)
#   [59/793] outlet=867 (3 pairs, 0 touching)
#   [60/793] outlet=896 (78 pairs, 7 touching)
#   [61/793] outlet=1078 (no pairs)
#   [62/793] outlet=1151 (595 pairs, 25 touching)
#   [63/793] outlet=1152 (no pairs)
#   [64/793] outlet=1210 (no pairs)
#   [65/793] outlet=1282 (15 pairs, 2 touching)
#   [66/793] outlet=1322 (7140 pairs, 100 touching)
#   [67/793] outlet=1542 (no pairs)
#   [68/793] outlet=1652 (no pairs)
#   [69/793] outlet=1682 (45 pairs, 5 touching)
#   [70/793] outlet=1758 (10 pairs, 2 touching)
#   [71/793] outlet=1759 (no pairs)
#   [72/793] outlet=1970 (no pairs)
#   [73/793] outlet=1971 (171 pairs, 9 touching)
#   [74/793] outlet=2052 (4656 pairs, 60 touching)
#   [75/793] outlet=2123 (no pairs)
#   [76/793] outlet=2250 (no pairs)
#   [77/793] outlet=2317 (1 pairs, 0 touching)
#   [78/793] outlet=2398 (no pairs)
#   [79/793] outlet=2399 (no pairs)
#   [80/793] outlet=2498 (6 pairs, 3 touching)
#   [81/793] outlet=2651 (91 pairs, 12 touching)
#   [82/793] outlet=2652 (no pairs)
#   [83/793] outlet=2653 (6 pairs, 1 touching)
#   [84/793] outlet=2743 (6 pairs, 2 touching)
#   [85/793] outlet=2828 (15 pairs, 2 touching)
#   [86/793] outlet=2831 (no pairs)
#   [87/793] outlet=3240 (no pairs)
#   [88/793] outlet=3241 (10 pairs, 5 touching)
#   [89/793] outlet=3541 (no pairs)
#   [90/793] outlet=3597 (no pairs)
#   [91/793] outlet=3994 (no pairs)
#   [92/793] outlet=4091 (no pairs)
#   [93/793] outlet=4176 (no pairs)
#   [94/793] outlet=4222 (no pairs)
#   [95/793] outlet=4551 (3 pairs, 0 touching)
#   [96/793] outlet=4715 (no pairs)
#   [97/793] outlet=4815 (15 pairs, 2 touching)
#   [98/793] outlet=4870 (no pairs)
#   [99/793] outlet=4978 (no pairs)
#   [100/793] outlet=4980 (no pairs)
#   [101/793] outlet=5084 (42486 pairs, 274 touching)
#   [102/793] outlet=5167 (no pairs)
#   [103/793] outlet=5356 (21 pairs, 4 touching)
#   [104/793] outlet=5418 (no pairs)
#   [105/793] outlet=5541 (no pairs)
#   [106/793] outlet=5766 (3 pairs, 1 touching)
#   [107/793] outlet=5933 (no pairs)
#   [108/793] outlet=5934 (no pairs)
#   [109/793] outlet=5990 (no pairs)
#   [110/793] outlet=5991 (no pairs)
#   [111/793] outlet=6160 (no pairs)
#   [112/793] outlet=6336 (no pairs)
#   [113/793] outlet=6430 (no pairs)
#   [114/793] outlet=6431 (3 pairs, 3 touching)
#   [115/793] outlet=6482 (no pairs)
#   [116/793] outlet=6610 (no pairs)
#   [117/793] outlet=6612 (no pairs)
#   [118/793] outlet=6688 (6 pairs, 2 touching)
#   [119/793] outlet=6745 (no pairs)
#   [120/793] outlet=6799 (1 pairs, 1 touching)
#   [121/793] outlet=6805 (no pairs)
#   [122/793] outlet=6868 (no pairs)
#   [123/793] outlet=6930 (no pairs)
#   [124/793] outlet=6934 (no pairs)
#   [125/793] outlet=6991 (no pairs)
#   [126/793] outlet=7134 (no pairs)
#   [127/793] outlet=7194 (4005 pairs, 84 touching)
#   [128/793] outlet=7201 (no pairs)
#   [129/793] outlet=7385 (no pairs)
#   [130/793] outlet=7389 (no pairs)
#   [131/793] outlet=7447 (15 pairs, 4 touching)
#   [132/793] outlet=7451 (no pairs)
#   [133/793] outlet=7452 (no pairs)
#   [134/793] outlet=7573 (1 pairs, 1 touching)
#   [135/793] outlet=7574 (no pairs)
#   [136/793] outlet=7719 (1 pairs, 1 touching)
#   [137/793] outlet=7724 (no pairs)
#   [138/793] outlet=7730 (no pairs)
#   [139/793] outlet=7807 (no pairs)
#   [140/793] outlet=7870 (no pairs)
#   [141/793] outlet=8027 (210 pairs, 9 touching)
#   [142/793] outlet=8031 (no pairs)
#   [143/793] outlet=8041 (no pairs)
#   [144/793] outlet=8105 (3 pairs, 0 touching)
#   [145/793] outlet=8211 (no pairs)
#   [146/793] outlet=8213 (no pairs)
#   [147/793] outlet=8215 (no pairs)
#   [148/793] outlet=8281 (120 pairs, 6 touching)
#   [149/793] outlet=8297 (no pairs)
#   [150/793] outlet=8301 (no pairs)
#   [151/793] outlet=8306 (1 pairs, 1 touching)
#   [152/793] outlet=8390 (406 pairs, 21 touching)
#   [153/793] outlet=8397 (no pairs)
#   [154/793] outlet=8398 (no pairs)
#   [155/793] outlet=8404 (no pairs)
#   [156/793] outlet=8486 (no pairs)
#   [157/793] outlet=8568 (1 pairs, 0 touching)
#   [158/793] outlet=8571 (no pairs)
#   [159/793] outlet=8583 (no pairs)
#   [160/793] outlet=8586 (no pairs)
#   [161/793] outlet=8682 (no pairs)
#   [162/793] outlet=8683 (no pairs)
#   [163/793] outlet=8687 (no pairs)
#   [164/793] outlet=8768 (no pairs)
#   [165/793] outlet=8781 (no pairs)
#   [166/793] outlet=8782

# %% [markdown]
# ## 5. Results Summary

# %%
# Summary table
summary_rows = []

for basin_name, df in basin_results.items():
    if df.empty:
        continue
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    ref = get_reference_delta_L(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    # Compute statistics
    n_pairs = len(df)
    n_touching = df['touching'].sum()
    touch_pct = 100 * n_touching / n_pairs if n_pairs > 0 else 0
    
    # delta_L statistics
    delta_L_stats = compute_asymmetry_statistics(df['delta_L'].dropna())
    
    summary_rows.append({
        "Basin": config["full_name"],
        "z_th (m)": config["z_th"],
        "Total Pairs": n_pairs,
        "Touching Pairs": n_touching,
        "Touch %": f"{touch_pct:.1f}%",
        "delta_L median": f"{delta_L_stats['median']:.3f}",
        "delta_L (25-75%)": f"({delta_L_stats['p25']:.2f} - {delta_L_stats['p75']:.2f})",
        "Ref delta_L": f"{ref['median']:.2f} ({ref['p25']:.2f} - {ref['p75']:.2f})",
    })

df_summary = pd.DataFrame(summary_rows)
print("\n=== Analysis Summary - All 18 Basins ===")
print(df_summary.to_string(index=False))

# %%
# Show sample results for each basin
for basin_name, df in basin_results.items():
    if df.empty:
        continue
    
    print(f"\n=== {basin_name.upper()} - Sample Results ===")
    print(f"Columns: {list(df.columns)}")
    print()
    # Show touching pairs with asymmetry
    df_touching = df[df['touching'] == True].head(5)
    if not df_touching.empty:
        print("Sample touching pairs:")
        print(df_touching[['outlet', 'confluence', 'head_1', 'head_2', 'touching', 
                           'L_1', 'L_2', 'delta_L', 'overlap_px', 'contact_px']].to_string(index=False))
    else:
        print("No touching pairs found.")

# %% [markdown]
# ## 6. Lengthwise Asymmetry (delta_L) Distribution

# %%
# Plot delta_L distribution for all basins
n_basins = len(basin_results)
n_cols = 4
n_rows = (n_basins + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4*n_cols, 3*n_rows))
axes = np.atleast_1d(axes).flatten()

for idx, (basin_name, df) in enumerate(basin_results.items()):
    ax = axes[idx]
    
    if df.empty:
        ax.set_title(f"{basin_name}: No data")
        continue
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    ref = get_reference_delta_L(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    # Get delta_L values
    delta_L = df['delta_L'].dropna()
    stats = compute_asymmetry_statistics(delta_L)
    
    # Plot histogram
    ax.hist(delta_L, bins=30, alpha=0.7, edgecolor='black', label='Computed')
    
    # Add reference lines
    ax.axvline(stats['median'], color='blue', linestyle='-', linewidth=2, 
               label=f'Computed: {stats["median"]:.2f}')
    ax.axvline(ref['median'], color='red', linestyle='--', linewidth=2,
               label=f'Reference: {ref["median"]:.2f}')
    
    ax.set_xlabel('delta_L')
    ax.set_ylabel('Count')
    # Get short name (first part before comma)
    short_name = config["full_name"].split(',')[0]
    ax.set_title(f"{short_name}\n(n={len(delta_L)})")
    ax.legend(fontsize=7)
    ax.set_xlim(0, 2.5)

# Hide unused subplots
for idx in range(len(basin_results), len(axes)):
    axes[idx].set_visible(False)

plt.tight_layout()
plt.suptitle('Lengthwise Asymmetry Distribution - All 18 Basins', y=1.02, fontsize=14)
plt.show()

# %% [markdown]
# ## 7. Comparison with Paper Reference Values

# %%
# Create comparison plot
fig, ax = plt.subplots(figsize=(16, 8))

x_positions = []
computed_medians = []
computed_errors = []
reference_medians = []
reference_errors = []
labels = []

for i, basin_name in enumerate(basin_results.keys()):
    df = basin_results[basin_name]
    if df.empty:
        continue
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    ref = get_reference_delta_L(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    stats = compute_asymmetry_statistics(df['delta_L'].dropna())
    
    x_positions.append(len(x_positions))
    labels.append(config['full_name'].split(',')[0])  # Short name
    
    computed_medians.append(stats['median'])
    computed_errors.append([[stats['median'] - stats['p25']], [stats['p75'] - stats['median']]])
    
    reference_medians.append(ref['median'])
    reference_errors.append([[ref['median'] - ref['p25']], [ref['p75'] - ref['median']]])

# Plot
x = np.array(x_positions)
width = 0.35

# Computed values
ax.bar(x - width/2, computed_medians, width, label='Computed', color='steelblue', alpha=0.8)
for i, (pos, med, err) in enumerate(zip(x - width/2, computed_medians, computed_errors)):
    ax.errorbar(pos, med, yerr=err, fmt='none', color='black', capsize=3)

# Reference values
ax.bar(x + width/2, reference_medians, width, label='Paper Reference', color='coral', alpha=0.8)
for i, (pos, med, err) in enumerate(zip(x + width/2, reference_medians, reference_errors)):
    ax.errorbar(pos, med, yerr=err, fmt='none', color='black', capsize=3)

ax.set_ylabel('delta_L (Lengthwise Asymmetry)')
ax.set_title('Computed vs. Reference delta_L Values - All 18 Basins\n(Error bars show 25th-75th percentiles)')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()
ax.set_ylim(0, None)

plt.tight_layout()
plt.show()

# Print comparison table
print("\n=== Computed vs. Reference delta_L ===")
print(f"{'Basin':<40} {'Computed':<25} {'Reference':<25}")
print("-" * 90)
for basin_name, df in basin_results.items():
    if df.empty:
        continue
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    ref = get_reference_delta_L(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    stats = compute_asymmetry_statistics(df['delta_L'].dropna())
    
    comp_str = f"{stats['median']:.2f} ({stats['p25']:.2f}-{stats['p75']:.2f})"
    ref_str = f"{ref['median']:.2f} ({ref['p25']:.2f}-{ref['p75']:.2f})"
    print(f"{config['full_name']:<40} {comp_str:<25} {ref_str:<25}")

# %% [markdown]
# ## 8. Aridity Index vs. Lengthwise Asymmetry
#
# Scatter plot comparing aridity index with lengthwise asymmetry (delta_L) from the paper reference values, with error bars showing the 25th-75th percentile ranges for both variables.

# %%
# Scatter plot: Aridity Index vs. Lengthwise Asymmetry (delta_L)
# Comparing computed delta_L values with paper reference values

fig, ax = plt.subplots(figsize=(14, 10))

# Collect data for all analyzed basins
basin_names_list = []
aridity_vals = []
aridity_errs_lower = []
aridity_errs_upper = []
computed_delta_L = []
computed_delta_L_errs_lower = []
computed_delta_L_errs_upper = []
reference_delta_L = []
reference_delta_L_errs_lower = []
reference_delta_L_errs_upper = []

for basin_name, df in basin_results.items():
    if df.empty:
        continue
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    # Aridity index from paper
    aridity = config["aridity_index"]
    aridity_25 = config["aridity_index_25"]
    aridity_75 = config["aridity_index_75"]
    
    # Computed Delta L from our analysis
    stats = compute_asymmetry_statistics(df['delta_L'].dropna())
    
    # Reference Delta L from paper
    ref = get_reference_delta_L(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    basin_names_list.append(config['full_name'].split(',')[0])
    
    aridity_vals.append(aridity)
    aridity_errs_lower.append(aridity - aridity_25)
    aridity_errs_upper.append(aridity_75 - aridity)
    
    computed_delta_L.append(stats['median'])
    computed_delta_L_errs_lower.append(stats['median'] - stats['p25'])
    computed_delta_L_errs_upper.append(stats['p75'] - stats['median'])
    
    reference_delta_L.append(ref['median'])
    reference_delta_L_errs_lower.append(ref['median'] - ref['p25'])
    reference_delta_L_errs_upper.append(ref['p75'] - ref['median'])

# Plot computed values (blue circles)
for i in range(len(aridity_vals)):
    ax.errorbar(
        aridity_vals[i], computed_delta_L[i],
        xerr=[[aridity_errs_lower[i]], [aridity_errs_upper[i]]],
        yerr=[[computed_delta_L_errs_lower[i]], [computed_delta_L_errs_upper[i]]],
        fmt='o', markersize=12, capsize=5, capthick=2,
        color='dodgerblue', ecolor='dodgerblue', alpha=0.8,
        label='Computed' if i == 0 else None
    )

# Plot reference values (red squares)
for i in range(len(aridity_vals)):
    ax.errorbar(
        aridity_vals[i], reference_delta_L[i],
        xerr=[[aridity_errs_lower[i]], [aridity_errs_upper[i]]],
        yerr=[[reference_delta_L_errs_lower[i]], [reference_delta_L_errs_upper[i]]],
        fmt='s', markersize=10, capsize=5, capthick=2,
        color='crimson', ecolor='crimson', alpha=0.8,
        label='Paper Reference' if i == 0 else None
    )

# Draw lines connecting computed and reference for each basin
for i in range(len(aridity_vals)):
    ax.plot([aridity_vals[i], aridity_vals[i]], 
            [computed_delta_L[i], reference_delta_L[i]], 
            'k--', alpha=0.3, linewidth=1)

# Add labels to computed points
for i, label in enumerate(basin_names_list):
    # Position label above or below based on which point is higher
    if computed_delta_L[i] >= reference_delta_L[i]:
        y_pos = computed_delta_L[i]
        xytext = (8, 8)
    else:
        y_pos = reference_delta_L[i]
        xytext = (8, 8)
    
    ax.annotate(
        label, 
        (aridity_vals[i], y_pos),
        textcoords="offset points",
        xytext=xytext,
        fontsize=8,
        alpha=0.9
    )

ax.set_xlabel('Aridity Index', fontsize=12)
ax.set_ylabel('delta_L (Lengthwise Asymmetry)', fontsize=12)
ax.set_title('Aridity Index vs. Lengthwise Asymmetry: Computed vs. Reference (All 18 Basins)\n(Error bars show 25th-75th percentiles)', fontsize=12)
ax.legend(loc='upper left', fontsize=11, framealpha=0.9)
ax.grid(True, alpha=0.3)

# Set axis limits with some padding
all_delta_L = computed_delta_L + reference_delta_L
ax.set_xlim(0, max(aridity_vals) * 1.3)
ax.set_ylim(0, max(all_delta_L) * 1.2)

plt.tight_layout()
plt.show()

# Print comparison table
print("\n=== Aridity Index vs. delta_L Comparison ===")
print(f"{'Basin':<35} {'Aridity':<12} {'Computed delta_L':<22} {'Reference delta_L':<22}")
print("-" * 91)
for i, basin_name in enumerate(basin_results.keys()):
    if basin_results[basin_name].empty:
        continue
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    stats = compute_asymmetry_statistics(basin_results[basin_name]['delta_L'].dropna())
    ref = get_reference_delta_L(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    name = config['full_name'].split(',')[0]
    aridity_str = f"{config['aridity_index']:.2f}"
    computed_str = f"{stats['median']:.2f} ({stats['p25']:.2f}-{stats['p75']:.2f})"
    ref_str = f"{ref['median']:.2f} ({ref['p25']:.2f}-{ref['p75']:.2f})"
    print(f"{name:<35} {aridity_str:<12} {computed_str:<22} {ref_str:<22}")

# %% [markdown]
# ## 9. Concavity (theta) vs. Lengthwise Asymmetry

# %%
# Scatter plot: Concavity (theta) vs. Lengthwise Asymmetry (delta_L)

fig, ax = plt.subplots(figsize=(14, 10))

# Collect data
theta_vals = []
theta_errs_lower = []
theta_errs_upper = []

for basin_name, df in basin_results.items():
    if df.empty:
        continue
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    theta_vals.append(config["theta"])
    theta_errs_lower.append(config["theta"] - config["theta_25"])
    theta_errs_upper.append(config["theta_75"] - config["theta"])

# Plot computed values (blue circles)
for i in range(len(theta_vals)):
    ax.errorbar(
        theta_vals[i], computed_delta_L[i],
        xerr=[[theta_errs_lower[i]], [theta_errs_upper[i]]],
        yerr=[[computed_delta_L_errs_lower[i]], [computed_delta_L_errs_upper[i]]],
        fmt='o', markersize=12, capsize=5, capthick=2,
        color='dodgerblue', ecolor='dodgerblue', alpha=0.8,
        label='Computed' if i == 0 else None
    )

# Plot reference values (red squares)
for i in range(len(theta_vals)):
    ax.errorbar(
        theta_vals[i], reference_delta_L[i],
        xerr=[[theta_errs_lower[i]], [theta_errs_upper[i]]],
        yerr=[[reference_delta_L_errs_lower[i]], [reference_delta_L_errs_upper[i]]],
        fmt='s', markersize=10, capsize=5, capthick=2,
        color='crimson', ecolor='crimson', alpha=0.8,
        label='Paper Reference' if i == 0 else None
    )

# Draw lines connecting computed and reference for each basin
for i in range(len(theta_vals)):
    ax.plot([theta_vals[i], theta_vals[i]], 
            [computed_delta_L[i], reference_delta_L[i]], 
            'k--', alpha=0.3, linewidth=1)

# Add labels
for i, label in enumerate(basin_names_list):
    if computed_delta_L[i] >= reference_delta_L[i]:
        y_pos = computed_delta_L[i]
        xytext = (8, 8)
    else:
        y_pos = reference_delta_L[i]
        xytext = (8, 8)
    
    ax.annotate(
        label, 
        (theta_vals[i], y_pos),
        textcoords="offset points",
        xytext=xytext,
        fontsize=8,
        alpha=0.9
    )

ax.set_xlabel('Concavity (theta)', fontsize=12)
ax.set_ylabel('delta_L (Lengthwise Asymmetry)', fontsize=12)
ax.set_title('Concavity vs. Lengthwise Asymmetry: Computed vs. Reference (All 18 Basins)\n(Error bars show 25th-75th percentiles)', fontsize=12)
ax.legend(loc='upper left', fontsize=11, framealpha=0.9)
ax.grid(True, alpha=0.3)

ax.set_xlim(0, max(theta_vals) * 1.2)
ax.set_ylim(0, max(all_delta_L) * 1.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Basin Overview Visualizations
#
# Plot basin overviews for selected basins with the most touching pairs.

# %%
# Plot basin overview for a subset of basins (to avoid too many plots)
# Select basins with most touching pairs
basin_touching_counts = {}
for basin_name, df in basin_results.items():
    if not df.empty:
        basin_touching_counts[basin_name] = df['touching'].sum()

# Sort by touching counts and select top 6
top_basins = sorted(basin_touching_counts.items(), key=lambda x: x[1], reverse=True)[:6]
print(f"Showing basin overviews for top 6 basins by touching pair count:")
for name, count in top_basins:
    print(f"  {name}: {count} touching pairs")

for basin_name, _ in top_basins:
    data = basin_data[basin_name]
    df = basin_results[basin_name]
    
    if df.empty:
        continue
    
    # Get the outlet with most touching pairs
    touching_counts = df[df['touching']].groupby('outlet').size()
    if touching_counts.empty:
        pair_counts = df.groupby('outlet').size()
        best_outlet = pair_counts.idxmax()
    else:
        best_outlet = touching_counts.idxmax()
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    print(f"\n{'='*60}")
    print(f"{config['full_name']} - Outlet {best_outlet}")
    print(f"{'='*60}")
    
    # Plot outlet view
    fig, ax = plot_outlet_view(
        s=data["s"],
        outlet_id=best_outlet,
        dem=data["dem"],
        view_mode="crop",
        pad_frac=0.1,
    )
    ax.set_title(f"{config['full_name']}\nOutlet {best_outlet} - Basin Overview")
    plt.show()

# %% [markdown]
# ## 11. Coupled Channel Head Pairs Visualization

# %%
# Plot coupled pairs for top basins
for basin_name, _ in top_basins[:3]:  # Limit to top 3
    data = basin_data[basin_name]
    df = basin_results[basin_name]
    
    if df.empty:
        continue
    
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    
    # Get touching pairs sorted by delta_L (highest asymmetry first)
    df_touching = df[df['touching'] == True].sort_values('delta_L', ascending=False)
    
    if df_touching.empty:
        print(f"\nNo touching pairs for {basin_name}")
        continue
    
    print(f"\n{'='*60}")
    print(f"{config['full_name']} - Coupled Pairs")
    print(f"Total touching pairs: {len(df_touching)}")
    print(f"{'='*60}")
    
    # Plot top 2 pairs with highest asymmetry
    for i, row in enumerate(df_touching.head(2).itertuples()):
        print(f"\nPair {i+1}: heads ({row.head_1}, {row.head_2}) at confluence {row.confluence}")
        print(f"  L_1={row.L_1:.1f}m, L_2={row.L_2:.1f}m, delta_L={row.delta_L:.3f}")
        print(f"  Overlap: {row.overlap_px}px, Contact: {row.contact_px}px")
        
        try:
            fig, ax = plot_coupled_pair(
                fd=data["fd"],
                s=data["s"],
                dem=data["dem"],
                confluence_id=int(row.confluence),
                head_i=int(row.head_1),
                head_j=int(row.head_2),
                view_mode="crop",
                pad_frac=0.1,
                focus="masks",
            )
            ax.set_title(f"{config['full_name']}\nHeads {row.head_1}, {row.head_2} | delta_L={row.delta_L:.3f}")
            plt.show()
        except Exception as e:
            print(f"  Error plotting: {e}")

# %% [markdown]
# ## 12. Export Combined Results

# %%
# Combine all results into a single DataFrame
all_results = []
for basin_name, df in basin_results.items():
    if df.empty:
        continue
    df_copy = df.copy()
    df_copy['basin'] = basin_name
    config = get_basin_config(BASINS_TO_ANALYZE[basin_name]["paper_name"])
    df_copy['basin_full_name'] = config['full_name']
    df_copy['z_th'] = config['z_th']
    df_copy['lat'] = config['lat']
    df_copy['theta'] = config['theta']
    df_copy['aridity_index'] = config['aridity_index']
    all_results.append(df_copy)

df_all = pd.concat(all_results, ignore_index=True)

# Save combined results
combined_output_path = OUTPUT_DIR / "all_basins_combined_results.csv"
df_all.to_csv(combined_output_path, index=False)
print(f"\nSaved combined results to: {combined_output_path}")
print(f"Total pairs across all basins: {len(df_all)}")
print(f"Total touching pairs: {df_all['touching'].sum()}")
print(f"\nBasins included: {df_all['basin'].nunique()}")
print(df_all['basin'].value_counts())

# %% [markdown]
# ## Summary
#
# This notebook analyzed **all 18 basins** from Goren & Shelef (2024) for coupled channel heads and lengthwise asymmetry:
#
# 1. **Coupling Analysis**: Identified channel head pairs whose drainage basins touch or overlap
# 2. **Lengthwise Asymmetry (delta_L)**: Computed using flow path lengths
# 3. **Comparison**: Results compared with reference values from the paper
# 4. **Climate Relationship**: Explored the relationship between aridity index and lengthwise asymmetry
# 5. **Concavity Relationship**: Explored the relationship between channel concavity (theta) and lengthwise asymmetry
#
# Key findings:
# - The `z_th` elevation thresholds from the paper were applied to mask each DEM
# - Stream networks were extracted with a configurable threshold (default: 145 contributing pixels)
# - delta_L values measure the normalized difference in flow path lengths between paired channel heads
# - Results are saved both per-basin and as a combined dataset for further analysis
